# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset_Facebook.csv",sep=";") 
#seperator is semicolon

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
#create data subsets
#creating a subset of type=photos

# %%
df_photo=df.loc[df["Type"]=="Photo"]
df_photo.head(5)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
#creating a subset of type=status

df_status=df.loc[df["Type"]=="Status"]
df_status.head(5)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#creating a subset of type=video

df_video=df.loc[df["Type"]=="Video"]
df_video.head(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
#creating a subset of type=Link

df_link=df.loc[df["Type"]=="Link"]
df_link.head(5)
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#Merge Data
#merging subsets of photos and status

# %%
df_merged_ps=pd.concat([df_photo,df_status])
df_merged_ps
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
#merged subsets
print("Photo subset shape: ")
df_photo.shape
# Out:
# Photo subset shape:
# (426, 19)

# %%
print("Status subset shape: ")
df_status.shape
# Out:
# Status subset shape:
# (45, 19)

# %%
print("Merged subset shape: ")
df_merged_ps.shape
# no of rows=> 426+45=471
# Out:
# Merged subset shape:
# (471, 19)

# %%
#sort the data by columns

# %%
#sorting by the column by like
df_sort_like = df.sort_values(by=["like"])
df_sort_like
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
#sorting by the column by comment
df_sort_comments = df.sort_values(by=["comment"])
df_sort_comments
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 111            136736   Photo         1          10             6          8
# 276            126424   Photo         3           7             3          4
# 282            126345  Status         2           6             7         11
# 286            126141   Photo         1           6             5         11
# ..                ...     ...       ...         ...           ...        ...
# 228            131728   Photo         2           7             4          3
# 288            126141   Photo         1           6             4         12
# 168            135428   Photo         1           9             3         10
# 460             92507   Photo         3           2             1         13
# 244            130791   Photo         2           7             3          5
#
# ...

# %%
#sorting by the column = share
df_sort_share = df.sort_values(by=["share"])
df_sort_share
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 441             98195  Photo         1           3             5          4
# 21             138414  Photo         1          12             7         10
# 436            100732  Photo         1           3             6         13
# 431            100732  Photo         1           3             7         12
# 117            136642  Photo         1          10             7         11
# ..                ...    ...       ...         ...           ...        ...
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
# 120            136393  Photo         1          10             7          9
# 124            136393  Photo         1          10             7          6
# 164            135428  Photo         1           9             5         10
#
# ...

# %%
#Transposing Data

# %%
#transposing the dataset basically means interchanging the rows and columns

df_transpose = df.transpose()
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
#shape and reshape data

# %%
#adding an index column to provide a unique value to each row entry to further melt and unmelt the data

df['index'] = range(1,len(df)+1)
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#melting the data using melt()

df_melted = pd.melt(df, id_vars='index',  value_vars='Total Interactions')
df_melted
# Out:
#      index            variable  value
# 0        1  Total Interactions    100
# 1        2  Total Interactions    164
# 2        3  Total Interactions     80
# 3        4  Total Interactions   1777
# 4        5  Total Interactions    393
# ..     ...                 ...    ...
# 495    496  Total Interactions     84
# 496    497  Total Interactions     75
# 497    498  Total Interactions    115
# 498    499  Total Interactions    136
# 499    500  Total Interactions    119
#
# [500 rows x 3 columns]

# %%
#melting the data using melt()

df_melted = pd.melt(df, id_vars='index',  value_vars='Type')
df_melted
# Out:
#      index variable   value
# 0        1     Type   Photo
# 1        2     Type  Status
# 2        3     Type   Photo
# 3        4     Type   Photo
# 4        5     Type   Photo
# ..     ...      ...     ...
# 495    496     Type   Photo
# 496    497     Type   Photo
# 497    498     Type   Photo
# 498    499     Type   Photo
# 499    500     Type   Photo
#
# [500 rows x 3 columns]

# %%
df.pivot_table('Type','like','Category', fill_value = 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# ...
